# %% [markdown]
# Visual-Spatial Intelligence Benchmark (VSI-Bench & VSI-Bench-Debiased)
#
# https://huggingface.co/datasets/nyu-visionx/VSI-Bench
#
# https://vision-x-nyu.github.io/thinking-in-space.github.io/
#
# https://github.com/vision-x-nyu/thinking-in-space
#
# Paper: https://arxiv.org/pdf/2412.14171

# %%
import pandas as pd
from PIL import Image

df = pd.read_csv("DISE-benchmark.csv", engine="python", on_bad_lines="skip")

row = df.iloc[0]
img = Image.open(row["question_image_path"]).convert("RGB")

question = row["question"]
choices = [row[f"option_{i}"] for i in range(4)]
answer = row["answer"]
